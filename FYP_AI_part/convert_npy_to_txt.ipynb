# %% [markdown]
# This file is to convert the .npy file into .txt file, and save into the drive

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

directory = 'Colab Notebooks/FYP/data/'  # Change this to your path
import os
import numpy as np
unzipped_directory2 = '/content/drive/MyDrive/Colab Notebooks/FYP/data/alotofzipped/hairpin-traces-main'
# Out:
# Mounted at /content/drive

# %%
# Load the .npy file
loaded_data = np.load('/content/drive/MyDrive/Colab Notebooks/FYP/data/extracted_data.npy', allow_pickle=True)

# %%
print(loaded_data.shape)
# Out:
# (1450, 30000, 3)

# %%
# Load the .npy file
# Select one sample to save (e.g., the first sample)

sample_index = 1

sample_data = loaded_data[sample_index]
print(sample_data.shape)
# Save the sample data to a .txt file
output_file_path = '/content/drive/MyDrive/Colab Notebooks/FYP/data/parameters.txt'
np.savetxt(output_file_path, sample_data, fmt='%.6f', delimiter=',')

print(f"Sample data saved to {output_file_path}")
# Out:
# (30000, 3)
# Sample data saved to /content/drive/MyDrive/Colab Notebooks/FYP/data/parameters.txt
